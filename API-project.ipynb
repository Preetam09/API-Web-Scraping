# %% [markdown]
# ## TMDB access key - d7b89468774f69cbd35a8ebd3fdea241

# %% [markdown]
# ## Access toekn v4 - eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkN2I4OTQ2ODc3NGY2OWNiZDM1YThlYmQzZmRlYTI0MSIsInN1YiI6IjYxZTY3ZGMxMjYzNDYyMDA5Njg2ZmRmYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.epmOaglUcXVRPK_OT_j2CXc5n1c6DSEtcfItKQS9lWg

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/search/movie',params = {'query': 'Andhadhun','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
a['results'][0]['id']
# Out:
# 534780

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/search/company',params = {'query': 'Marvel Studios','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
a['results'][0]['id']
# Out:
# {'page': 1,
#  'results': [{'id': 420,
#    'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#    'name': 'Marvel Studios',
#    'origin_country': 'US'}],
#  'total_pages': 1,
#  'total_results': 1}

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/search/movie',params = {'query': '3 Idiots','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
id = a['results'][0]['id']
url = 'https://api.themoviedb.org/3/movie/'+str(id)
r  = requests.get(url,params = {'query': '3 Idiots','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
ans = r.json()
print(ans['vote_count'],ans['vote_average'])
# Out:
# 1753 8.0

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/search/movie',params = {'query': 'Inception','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
id = a['results'][0]['id']
url = 'https://api.themoviedb.org/3/movie/846190/similar'
r  = requests.get(url,params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
ans = r.json()
for i in ans['results']:
    print(i['title'])
id
# Out:
# Inception
# Man of Tai Chi
# The Intouchables
# Spring Breakers
# Rush
# Anna Karenina
# The Walking Dead
# Diana
# I Want You
# Erotic Ghost Story III
# Compliance
# The First Time
# Rock of Ages
# Desire
# The Counselor
# Snowpiercer
# Wolf Children
# Liberated
# Flight
# Oldboy
# 27205

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/search/movie',params = {'query': 'Inception','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
id = a['results'][0]['id']
a
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/s3TBrRGB1iav7gFOCNx3H31MoES.jpg',
#    'genre_ids': [28, 878, 12],
#    'id': 27205,
#    'original_language': 'en',
#    'original_title': 'Inception',
#    'overview': 'Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.',
#    'popularity': 174.581,
#    'poster_path': '/9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg',
#    'release_date': '2010-07-15',
#    'title': 'Inception',
#    'video': False,
#    'vote_average': 8.4,
#    'vote_count': 30738},
#   {'adult': False,
#    'backdrop_path': '/sABMpHRCmt7qg9q6AFbZ1jPU1Jf.jpg',
#    'genre_ids': [16, 28, 53, 878],
#    'id': 64956,
#    'original_language': 'en',
#    'original_title': 'Inception: The Cobol Job',
# ...

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/movie/846190',params = {'query': 'Inception','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
a
# Out:
# {'adult': False,
#  'backdrop_path': '/vYJRSrZmUcL7FPhOeCk3n6rFRRp.jpg',
#  'belongs_to_collection': None,
#  'budget': 0,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'name': 'Mystery'}],
#  'homepage': '',
#  'id': 846190,
#  'imdb_id': 'tt7321322',
#  'original_language': 'fa',
#  'original_title': 'Aghaz',
#  'overview': 'Young man (Erfan) wants to do something important,It has a lot of risk for him But he must make a decision,Though everyone around them opposes doing so,The boy decides that...',
#  'popularity': 0.6,
#  'poster_path': '/jYxQqa3ZaXhhG89YEUZkxUfKFdm.jpg',
#  'production_companies': [{'id': 156009,
#    'logo_path': '/sOcs3Nc7jeW9aSMjm4K9XptYxth.png',
#    'name': 'Bidel Irania',
#    'origin_country': 'IR'}],
#  'production_countries': [{'iso_3166_1': 'IR', 'name': 'Iran'}],
#  'release_date': '2014-02-12',
#  'revenue': 0,
#  'runtime': 11,
#  'spoken_languages': [{'english_name': 'Persian',
#    'iso_639_1': 'fa',
#    'name': 'فارسی'}],
# ...

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
id = []
for j in range(1,10):
    g = requests.get('https://api.themoviedb.org/3/movie/top_rated',params = {'page':j,'language': 'en-US','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
    a = g.json()
    ans = a['results']
    for i in ans:
        if i['original_language'] == 'en':
            id.append(i['id'])
j = 0 
for i in id:
    url = 'https://api.themoviedb.org/3/movie/'+str(i)
    m = requests.get(url,params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
    req = m.json()
    #print(ans)
    if (req['production_companies'][0]['origin_country'] == 'US') and (j<5):
        print(req['title'],'-',end = ' ')
        k = 0
        for i in req['genres']:
            print(i['name'],end = '')
            print(', ',end = '')
        print()
        j = j+1
# Out:
# The Shawshank Redemption - Drama, Crime,
# The Godfather - Drama, Crime,
# Gabriel's Inferno Part II - Romance,
# Schindler's List - Drama, History, War,
# Gabriel's Inferno - Romance,

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/person/popular',params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
id = a['results'][0]['id']
url = 'https://api.themoviedb.org/3/person/'+str(id)
r = requests.get(url,params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
l = r.json()
print(id)
print(l['name'],'-',l['place_of_birth'])
# Out:
# 169337
# Katherine LaNasa - New Orleans, Louisiana, USA

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/search/person',params = {'query':'Alia Bhatt','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
id = a['results'][0]['id']
url = 'https://api.themoviedb.org/3/person/'+str(id)+'/external_ids'
r = requests.get(url,params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
l = r.json()
print(l['instagram_id'],l['twitter_id'])
# Out:
# aliaabhatt Aliaa08

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
movie = ['Top Gun','Mission: Impossible - Fallout','Minority Report','Edge of Tomorrow']
for z in movie:
    g = requests.get('https://api.themoviedb.org/3/search/movie',params = {'query':z,'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
    a = g.json()
    url = 'https://api.themoviedb.org/3/movie/'+str(a['results'][0]['id'])+'/credits'
    c =  requests.get(url,params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
    cid = c.json()
    print(cid['cast'][0]['character'])
# Out:
# Lt. Pete 'Maverick' Mitchell
# Ethan Hunt
# Chief John Anderton
# Maj. William "Bill" Cage

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/search/tv',params = {'query':'FRIENDS','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
id = a['results'][0]['id']
url = 'https://api.themoviedb.org/3/tv/'+str(id)
t = requests.get(url,params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
ans = t.json()
ans['overview']
# Out:
# 'Friends is an American television sitcom created by David Crane and Marta Kauffman, which aired on NBC from September 22, 1994, to May 6, 2004, lasting ten seasons. With an ensemble cast starring Jennifer Aniston, Courteney Cox, Lisa Kudrow, Matt LeBlanc, Matthew Perry and David Schwimmer, the show revolves around six friends in their 20s and 30s who live in Manhattan, New York City. The series was produced by Bright/Kauffman/Crane Productions, in association with Warner Bros. Television. The original executive producers were Kevin S. Bright, Kauffman, and Crane.'

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/search/tv',params = {'query':'The Big Bang Theory','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
id = a['results'][0]['id']
url = 'https://api.themoviedb.org/3/tv/'+str(id)+'/season/6/episode/5'
t = requests.get(url,params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
ans = t.json()
print(ans['name'],ans['air_date'])
# Out:
# The Holographic Excitation 2012-10-25

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/trending/tv/week',params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
for i in a['results'][0:5]:
    id = i['id']
    url = 'https://api.themoviedb.org/3/tv/'+str(id)
    m = requests.get(url,params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
    t = m.json()
    if t['tagline'] == '':
        print('Empty')
    else:
        print(t['tagline'])
# Out:
# Every galaxy has an underworld.
# Remember this feeling.
# Give peace a f#cking chance.
# Empty
# Empty

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/trending/tv/week',params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
a
# Out:
# {'page': 1,
#  'results': [{'backdrop_path': '/sjx6zjQI2dLGtEL0HGWsnq6UyLU.jpg',
#    'genre_ids': [10765, 10759],
#    'original_language': 'en',
#    'vote_count': 433,
#    'poster_path': '/gNbdjDi1HamTCrfvM9JeA94bNi2.jpg',
#    'vote_average': 8.1,
#    'id': 115036,
#    'original_name': 'The Book of Boba Fett',
#    'origin_country': ['US'],
#    'overview': 'Legendary bounty hunter Boba Fett and mercenary Fennec Shand must navigate the galaxy’s underworld when they return to the sands of Tatooine to stake their claim on the territory once ruled by Jabba the Hutt and his crime syndicate.',
#    'first_air_date': '2021-12-29',
#    'name': 'The Book of Boba Fett',
#    'popularity': 2429.15,
#    'media_type': 'tv'},
#   {'backdrop_path': '/oKt4J3TFjWirVwBqoHyIvv5IImd.jpg',
#    'genre_ids': [18],
#    'original_language': 'en',
#    'vote_count': 5564,
#    'poster_path': '/jtnfNzqZwN4E32FGGxx1YZaBWWf.jpg',
#    'vote_average': 8.4,
#    'id': 85552,
# ...

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
g = requests.get('https://api.themoviedb.org/3/search/tv',params = {'query':'Money Heist','api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
a = g.json()
id = a['results'][0]['id']
url = 'https://api.themoviedb.org/3/tv/'+str(id)+'/credits'
c = requests.get(url,params = {'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
j = c.json()
ct = j['cast']
d = {'m': 0 ,'f':0}
for i in ct:
    if i['gender'] == 2:
        d['m']+=1
    else:
        d['f']+=1
for i in d:
    print(d[i],end = ' ')
# Out:
# 10 5

# %%
import requests
import json
from requests.auth import HTTPBasicAuth
for j in range(1,16):
    g = requests.get('https://api.themoviedb.org/3/tv/airing_today',params = {'page' : j,'api_key' :'d7b89468774f69cbd35a8ebd3fdea241'})
    a = g.json()
    for i in a['results']:
        if i['original_language']=='en':
                print(i['name'])
# Out:
# Wheel of Fortune
# People Puzzler
# Peacemaker
# And Just Like That…
# Law & Order: Special Victims Unit
# Hollyoaks
# Tug of Words
# The Blacklist
# Chain Reaction
# General Hospital
# Days of Our Lives
# The Ellen DeGeneres Show
# Young Sheldon
# The Tonight Show Starring Jimmy Fallon
# Hot Bench
# Let's Make a Deal
# The View
# Walker
# Law & Order: Organized Crime
# Jimmy Kimmel Live!
# Judge Jerry
# The Steve Wilkos Show
# VICE News Tonight
# Bull
# Star Trek: Prodigy
# Good Mythical Morning
# Watch What Happens: Live
# Junior Bake Off
# The Bold and the Beautiful
# Project Runway
# Looney Tunes Cartoons
# Coroner
# Question Time
# LIVE with Kelly and Ryan
# Lingo
# Critical Role
# Tamron Hall
# EastEnders
# Hot Ones
# Hudson & Rex
# Full Frontal with Samantha Bee
# Dr. Phil
# Ghosts
# The Young and the Restless
# United States of Al
# WWE Main Event
# This Old House
# B Positive
# Call Me Kat
# Women of the Movement
# BattleBots
# Dragons' Den
# Pivoting
# The Apprentice
# ...

# %%
# Out:
# {'page': 1, 'results': [{'backdrop_path': '/yfXSvNfF43S0cxpxCEKaU17yZ64.jpg', 'first_air_date': '1983-09-19', 'genre_ids': [10751], 'id': 2778, 'name': 'Wheel of Fortune', 'origin_country': ['US'], 'original_language': 'en', 'original_name': 'Wheel of Fortune', 'overview': 'This game show sees contestants solve word puzzles, similar to those used in Hangman, to win cash and prizes determined by spinning a giant carnival wheel.', 'popularity': 1753.805, 'poster_path': '/2fvAIyVfFHQdhJ7OsJWuMlF7836.jpg', 'vote_average': 6.8, 'vote_count': 41}, {'backdrop_path': '/vjcuLy14kxgxCaBToAudZWrGQQh.jpg', 'first_air_date': '2021-01-18', 'genre_ids': [], 'id': 117031, 'name': 'People Puzzler', 'origin_country': [], 'original_language': 'en', 'original_name': 'People Puzzler', 'overview': 'Three lucky contestants put their pop culture knowledge to the test to complete iconic, People Puzzler crosswords. The player with the most points at the end of three rounds wins the game and goes on to play th
# ...
